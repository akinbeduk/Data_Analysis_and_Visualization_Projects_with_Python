# %% [markdown]
# <a href="https://colab.research.google.com/github/akinbeduk/DataAnalysisProjects/blob/main/Question4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
df=pd.read_csv("country_vaccination_stats.csv")

# %% [markdown]
# **4. Code Implementation Task: Implement code to fill the missing data (impute) in daily_vaccinations column per country with the minimum daily vaccination number of relevant countries.
# Note: If a country does not have any valid vaccination number yet, fill it with “0” (zero).
# Please  provide the link to your code as answer to this question.**

# %%
df.daily_vaccinations=df.groupby("country")["daily_vaccinations"].transform(lambda x: x.fillna(0 if x.sum()==0 else x.min()))
